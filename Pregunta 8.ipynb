# %% [markdown]
# # Pregunta
# ## ¿En qué tiempo prudente se realizan las cotizaciones?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

allstate=pd.read_csv("allstate.csv")

# %%
d = allstate[(allstate.record_type == 1)]

# %%
d.count()
d.time.mode()
# Out:
# 0    14:35
# dtype: object

# %%
print d
# Out:
#         customer_ID  shopping_pt  record_type  day   time state  location  \
# 8          10000000            9            1    0  12:07    IN     10001
# 14         10000005            6            1    3  09:09    NY     10006
# 22         10000007            8            1    4  14:26    PA     10008
# 26         10000013            4            1    4  09:31    WV     10014
# 32         10000014            6            1    1  17:50    MO     10015
# 42         10000016           10            1    3  13:15    OH     10018
# 50         10000019            8            1    1  11:34    OK     10021
# 57         10000023            7            1    1  14:32    PA     10025
# 64         10000025            7            1    0  15:26    OH     10027
# 68         10000026            4            1    3  15:24    OH     10028
# 74         10000027            6            1    2  08:03    IN     10029
# 80         10000028            6            1    6  11:44    FL     10030
# ...

# %% [markdown]
# El tiempo promedio para hacer cotizaciones es a las 2:35 de la manana segun los patrones mostrados.
